# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import colors
import seaborn as sns

# %%
data_NPI_17 = pd.read_csv('Medicare_Provider_Util_Payment_PUF_CY2017.txt', sep = '\t')
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_NPI_17 = data_NPI_17.iloc[1:]

# %%
data_NPI_17.head(5)
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
# 5  1003000126                    ENKESHAFI                   ARDALAN
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
# 5               NaN              M.D.                     M                 I
#
#   nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# ...

# %%
data_NPI_16 = pd.read_csv('Medicare_Provider_Util_Payment_PUF_CY2016.txt', sep = '\t')
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_NPI_16 = data_NPI_16.iloc[1:]

# %%
data_NPI_16.head(5)
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
# 5  1003000126                    ENKESHAFI                   ARDALAN
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
# 5               NaN              M.D.                     M                 I
#
#   NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY  \
# ...

# %%
data_NPI_15 = pd.read_csv('Medicare_Provider_Util_Payment_PUF_CY2015.txt', sep = '\t')
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_NPI_15 = data_NPI_15.iloc[1:]

# %%
data_NPI_15.head(5)
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
# 5  1003000126                    ENKESHAFI                   ARDALAN
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
# 5               NaN              M.D.                     M                 I
#
#   nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# ...

# %%
data_NPI_14 = pd.read_csv('Medicare_Provider_Util_Payment_PUF_CY2014.txt', sep = '\t')
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_NPI_14 = data_NPI_14.iloc[1:]

# %%
data_NPI_14.head(5)
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
# 5  1003000126                    ENKESHAFI                   ARDALAN
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
# 5               NaN              M.D.                     M                 I
#
#   nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# ...

# %%
data_NPI_13 = pd.read_csv('Medicare_Provider_Util_Payment_PUF_CY2013.txt', sep = '\t')
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_NPI_13 = data_NPI_13.iloc[1:]

# %%
data_NPI_13.head(5)
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
# 5  1003000126                    ENKESHAFI                   ARDALAN
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
# 5               NaN              M.D.                     M                 I
#
#   NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY  \
# ...

# %%
data_NPI_12 = pd.read_csv('Medicare_Provider_Util_Payment_PUF_CY2012.txt', sep = '\t')
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_NPI_12 = data_NPI_12.iloc[1:]

# %%
data_NPI_12.head(5)
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
# 5  1003000126                    ENKESHAFI                   ARDALAN
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
# 5               NaN              M.D.                     M                 I
#
#   NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY  \
# ...

# %%
data_exclusions = pd.read_csv('LEIE_Database.csv')
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_exclusions.head(5)
# Out:
#   LASTNAME FIRSTNAME MIDNAME                        BUSNAME         GENERAL  \
# 0      NaN       NaN               14 LAWRENCE AVE PHARMACY        PHARMACY
# 1      NaN       NaN               143 MEDICAL EQUIPMENT CO     DME COMPANY
# 2      NaN       NaN             184TH STREET PHARMACY CORP  OTHER BUSINESS
# 3      NaN       NaN          1951 FLATBUSH AVENUE PHARMACY        PHARMACY
# 4      NaN       NaN          1ST COMMUNITY HEALTH CTR, LTD          CLINIC
#
#       SPECIALTY UPIN         NPI  DOB             ADDRESS       CITY STATE  \
# 0           NaN  NaN           0  NaN  14 LAWRENCE AVENUE  SMITHTOWN    NY
# 1  DME - OXYGEN  NaN           0  NaN    701 NW 36 AVENUE      MIAMI    FL
# 2      PHARMACY  NaN  1922348218  NaN       69 E 184TH ST      BRONX    NY
# 3           NaN  NaN           0  NaN   1951 FLATBUSH AVE   BROOKLYN    NY
# 4           NaN  NaN           0  NaN  3138 W CERMAK ROAD    CHICAGO    IL
#
# ...

# %%
data_exclusions.shape
# Out:
# (72313, 18)

# %%
data_NPI_17.columns = data_NPI_17.columns.str.upper()

# %%
data_NPI_15.columns = data_NPI_15.columns.str.upper()

# %%
data_NPI_14.columns = data_NPI_14.columns.str.upper()

# %%
# data_NPI_17.rename(columns = {'npi':'NPI'}, inplace = True)

# %%
# data_NPI_15.rename(columns = {'npi':'NPI'}, inplace = True)

# %%
# data_NPI_14.rename(columns = {'npi':'NPI'}, inplace = True)

# %%
data_NPI_17.head(2)
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
#
#   NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY  \
# 1           900 SETON DR                    NaN          CUMBERLAND
# 2           900 SETON DR                    NaN          CUMBERLAND
#
#                ...               HCPCS_CODE  \
# 1              ...                    99217
# 2              ...                    99218
#
#                                 HCPCS_DESCRIPTION HCPCS_DRUG_INDICATOR  \
# 1             Hospital observation care discharge                    N
# ...

# %%
data_new_17 = pd.merge(data_NPI_17, data_exclusions, on='NPI', how='inner')

# %%
# data_new_17.columns = data_new_17.columns.str.upper()

# %%
data_new_17.head(2)
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 0  1003811167                       SORELL                      PAUL
# 1  1003811167                       SORELL                      PAUL
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 0                 J              M.D.                     M                 I
# 1                 J              M.D.                     M                 I
#
#   NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY    ...     \
# 0           775 PARK AVE                STE 155          HUNTINGTON    ...
# 1           775 PARK AVE                STE 155          HUNTINGTON    ...
#
#           DOB             ADDRESS     CITY STATE    ZIP EXCLTYPE  EXCLDATE  \
# 0  19640107.0  863 LARKFIELD ROAD  COMMACK    NY  11725   1128b4  20171220
# 1  19640107.0  863 LARKFIELD ROAD  COMMACK    NY  11725   1128b4  20171220
#
#   REINDATE WAIVERDATE  WVRSTATE
# ...

# %%
data_new_16 = pd.merge(data_NPI_16, data_exclusions, on='NPI', how='inner')

# %%
data_new_16.head(2)
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 0  1003811167                       SORELL                      PAUL
# 1  1003811167                       SORELL                      PAUL
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 0                 J              M.D.                     M                 I
# 1                 J              M.D.                     M                 I
#
#   NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY    ...     \
# 0           775 PARK AVE                STE 155          HUNTINGTON    ...
# 1           775 PARK AVE                STE 155          HUNTINGTON    ...
#
#           DOB             ADDRESS     CITY STATE    ZIP EXCLTYPE  EXCLDATE  \
# 0  19640107.0  863 LARKFIELD ROAD  COMMACK    NY  11725   1128b4  20171220
# 1  19640107.0  863 LARKFIELD ROAD  COMMACK    NY  11725   1128b4  20171220
#
#   REINDATE WAIVERDATE  WVRSTATE
# ...

# %%
data_new_15 = pd.merge(data_NPI_15, data_exclusions, on='NPI', how='inner')

# %%
# data_new_15.columns = data_new_15.columns.str.upper()

# %%
data_new_15.head(2)
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 0  1003042441                        MANZO                      MARK
# 1  1003811167                       SORELL                      PAUL
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 0               NaN               NaN                     M                 I
# 1                 J              M.D.                     M                 I
#
#   NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY    ...     \
# 0   210 PARK AVE STE 163                    NaN           WORCESTER    ...
# 1           775 PARK AVE                STE 155          HUNTINGTON    ...
#
#           DOB                   ADDRESS       CITY STATE    ZIP EXCLTYPE  \
# 0  19760222.0  210 PARK AVENUE, APT 163  WORCESTER    MA   1609   1128b4
# 1  19640107.0        863 LARKFIELD ROAD    COMMACK    NY  11725   1128b4
#
#    EXCLDATE REINDATE WAIVERDATE  WVRSTATE
# ...

# %%
data_new_14 = pd.merge(data_NPI_14, data_exclusions, on='NPI', how='inner')

# %%
# data_new_14.columns = data_new_14.columns.str.upper()

# %%
data_new_14.head(2)
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 0  1003811167                       SORELL                      PAUL
# 1  1003811167                       SORELL                      PAUL
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 0                 J              M.D.                     M                 I
# 1                 J              M.D.                     M                 I
#
#   NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY    ...     \
# 0           775 PARK AVE                STE 155          HUNTINGTON    ...
# 1           775 PARK AVE                STE 155          HUNTINGTON    ...
#
#           DOB             ADDRESS     CITY STATE    ZIP EXCLTYPE  EXCLDATE  \
# 0  19640107.0  863 LARKFIELD ROAD  COMMACK    NY  11725   1128b4  20171220
# 1  19640107.0  863 LARKFIELD ROAD  COMMACK    NY  11725   1128b4  20171220
#
#   REINDATE WAIVERDATE  WVRSTATE
# ...

# %%
data_new_13 = pd.merge(data_NPI_13, data_exclusions, on='NPI', how='inner')

# %%
data_new_13.head(2)
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 0  1003042441                        MANZO                      MARK
# 1  1003042441                        MANZO                      MARK
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 0               NaN              PA-C                     M                 I
# 1               NaN              PA-C                     M                 I
#
#   NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY    ...     \
# 0          2 GRAFTON CMN                    NaN             GRAFTON    ...
# 1          2 GRAFTON CMN                    NaN             GRAFTON    ...
#
#           DOB                   ADDRESS       CITY STATE   ZIP EXCLTYPE  \
# 0  19760222.0  210 PARK AVENUE, APT 163  WORCESTER    MA  1609   1128b4
# 1  19760222.0  210 PARK AVENUE, APT 163  WORCESTER    MA  1609   1128b4
#
#    EXCLDATE REINDATE WAIVERDATE  WVRSTATE
# ...

# %%
data_new_12 = pd.merge(data_NPI_12, data_exclusions, on='NPI', how='inner')

# %%
data_new_12.head(2)
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 0  1003809195                       MACKEY                    JOSEPH
# 1  1003809195                       MACKEY                    JOSEPH
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 0                 T              M.D.                     M                 I
# 1                 T              M.D.                     M                 I
#
#   NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY    ...     \
# 0      104 NO. 7 HIGHWAY                SUITE B        BLUE SPRINGS    ...
# 1      104 NO. 7 HIGHWAY                SUITE B        BLUE SPRINGS    ...
#
#           DOB                   ADDRESS         CITY STATE    ZIP EXCLTYPE  \
# 0  19720422.0  5705 NE MISTY MEADOW WAY  LEES SUMMIT    MO  64064   1128b4
# 1  19720422.0  5705 NE MISTY MEADOW WAY  LEES SUMMIT    MO  64064   1128b4
#
#    EXCLDATE REINDATE WAIVERDATE  WVRSTATE
# ...

# %%
#data_exclusions2 = data_new_17.append([data_new_16, data_new_15, data_new_14, data_new_13, data_new_12])

# %%
frames = [data_new_17, data_new_16, data_new_15, data_new_14, data_new_13, data_new_12]

# %%
common_cols = list(set.intersection(*(set(df.columns) for df in frames)))

# %%
exclusions_NPI = pd.concat([df[common_cols] for df in frames], ignore_index=True)

# %%
exclusions_NPI
# Out:
#        EXCLDATE FIRSTNAME HCPCS_DRUG_INDICATOR  AVERAGE_SUBMITTED_CHRG_AMT  \
# 0      20171220      PAUL                    N                  105.000000
# 1      20171220      PAUL                    N                  130.000000
# 2      20180419   DOUGLAS                    N                  127.000000
# 3      20180419   DOUGLAS                    N                  186.516949
# 4      20180419   DOUGLAS                    N                   82.000000
# 5      20180419   DOUGLAS                    N                   37.923077
# 6      20180419   DOUGLAS                    N                  219.636364
# 7      20171120     GUVEN                    N                 4972.826087
# 8      20171120     GUVEN                    N                 2497.159091
# 9      20171120     GUVEN                    N                 2593.750000
# 10     20171120     GUVEN                    N                 5142.857143
# ...

# %%
exclusions_NPI = exclusions_NPI[sorted(exclusions_NPI.columns)]

# %%
exclusions_NPI
# Out:
#                              ADDRESS  AVERAGE_MEDICARE_ALLOWED_AMT  \
# 0                 863 LARKFIELD ROAD                     84.290000
# 1                 863 LARKFIELD ROAD                    123.460000
# 2            P O BOX 6000 #43665-013                     73.160000
# 3            P O BOX 6000 #43665-013                    107.550000
# 4            P O BOX 6000 #43665-013                     42.230000
# 5            P O BOX 6000 #43665-013                     26.150000
# 6            P O BOX 6000 #43665-013                    116.480000
# 7                      P O BOX 12843                    301.240000
# 8                      P O BOX 12843                    149.420000
# 9                      P O BOX 12843                    150.000000
# 10                     P O BOX 12843                    278.190000
# 11                     P O BOX 12843                    138.030000
# 12                     P O BOX 12843                    138.620000
# ...

# %%
exclusions_NPI.shape
# Out:
# (49323, 42)

# %%
data_new_17.shape
# Out:
# (1671, 43)

# %%
data_new_16.shape
# Out:
# (3815, 43)

# %%
data_new_15.shape
# Out:
# (6329, 43)

# %%
data_new_14.shape
# Out:
# (9513, 43)

# %%
data_new_13.shape
# Out:
# (12533, 45)

# %%
data_new_12.shape
# Out:
# (15462, 45)

# %%
list(exclusions_NPI)
# Out:
# ['ADDRESS',
#  'AVERAGE_MEDICARE_ALLOWED_AMT',
#  'AVERAGE_MEDICARE_PAYMENT_AMT',
#  'AVERAGE_SUBMITTED_CHRG_AMT',
#  'BENE_DAY_SRVC_CNT',
#  'BENE_UNIQUE_CNT',
#  'BUSNAME',
#  'CITY',
#  'DOB',
#  'EXCLDATE',
#  'EXCLTYPE',
#  'FIRSTNAME',
#  'GENERAL',
#  'HCPCS_CODE',
#  'HCPCS_DESCRIPTION',
#  'HCPCS_DRUG_INDICATOR',
#  'LASTNAME',
#  'LINE_SRVC_CNT',
#  'MEDICARE_PARTICIPATION_INDICATOR',
#  'MIDNAME',
#  'NPI',
#  'NPPES_CREDENTIALS',
#  'NPPES_ENTITY_CODE',
#  'NPPES_PROVIDER_CITY',
#  'NPPES_PROVIDER_COUNTRY',
#  'NPPES_PROVIDER_FIRST_NAME',
#  'NPPES_PROVIDER_GENDER',
#  'NPPES_PROVIDER_LAST_ORG_NAME',
#  'NPPES_PROVIDER_MI',
#  'NPPES_PROVIDER_STATE',
#  'NPPES_PROVIDER_STREET1',
#  'NPPES_PROVIDER_STREET2',
#  'NPPES_PROVIDER_ZIP',
#  'PLACE_OF_SERVICE',
#  'PROVIDER_TYPE',
#  'REINDATE',
#  'SPECIALTY',
#  'STATE',
#  'UPIN',
#  'WAIVERDATE',
#  'WVRSTATE',
#  'ZIP']

# %%
exclusions_NPI.dtypes
# Out:
# ADDRESS                              object
# AVERAGE_MEDICARE_ALLOWED_AMT        float64
# AVERAGE_MEDICARE_PAYMENT_AMT        float64
# AVERAGE_SUBMITTED_CHRG_AMT          float64
# BENE_DAY_SRVC_CNT                   float64
# BENE_UNIQUE_CNT                     float64
# BUSNAME                              object
# CITY                                 object
# DOB                                 float64
# EXCLDATE                              int64
# EXCLTYPE                             object
# FIRSTNAME                            object
# GENERAL                              object
# HCPCS_CODE                           object
# HCPCS_DESCRIPTION                    object
# HCPCS_DRUG_INDICATOR                 object
# LASTNAME                             object
# LINE_SRVC_CNT                       float64
# MEDICARE_PARTICIPATION_INDICATOR     object
# MIDNAME                              object
# NPI                                   int64
# ...

# %%
data_new_17['NPPES_PROVIDER_ZIP'] = data_new_17.NPPES_PROVIDER_ZIP.astype(str)

# %%
data_new_17['NPPES_PROVIDER_ZIP'] = data_new_17['NPPES_PROVIDER_ZIP'].str[:5]

# %%
data_new_17['EXCLDATE'] = data_new_17.EXCLDATE.astype(str)

# %%
data_new_17['EXCLDATE'] = pd.to_datetime(data_new_17['EXCLDATE'], format = "%Y/%m/%d")

# %%
data_new_17['EXCLYEAR'] = data_new_17['EXCLDATE'].dt.year

# %%
data_new_17['EXCLYEAR'] = data_new_17.EXCLYEAR.astype(str)

# %%
data_new_17['DOB'] = data_new_17.DOB.astype(str)

# %%
data_new_17['DOB'] = data_new_17['DOB'].str.strip('.0')

# %%
data_new_17['DOB'] = pd.to_datetime(data_new_17['DOB'], format = "%Y/%m/%d", errors = 'coerce')

# %%
data_new_17['ZIP'] = data_new_17.ZIP.astype(str)

# %%
data_new_17.shape
# Out:
# (1671, 44)

# %%
data_new_17.dtypes
# Out:
# NPI                                          int64
# NPPES_PROVIDER_LAST_ORG_NAME                object
# NPPES_PROVIDER_FIRST_NAME                   object
# NPPES_PROVIDER_MI                           object
# NPPES_CREDENTIALS                           object
# NPPES_PROVIDER_GENDER                       object
# NPPES_ENTITY_CODE                           object
# NPPES_PROVIDER_STREET1                      object
# NPPES_PROVIDER_STREET2                      object
# NPPES_PROVIDER_CITY                         object
# NPPES_PROVIDER_ZIP                          object
# NPPES_PROVIDER_STATE                        object
# NPPES_PROVIDER_COUNTRY                      object
# PROVIDER_TYPE                               object
# MEDICARE_PARTICIPATION_INDICATOR            object
# PLACE_OF_SERVICE                            object
# HCPCS_CODE                                  object
# HCPCS_DESCRIPTION                           object
# ...

# %%
# strip trailing spaces after the exclusion types
data_new_17['EXCLTYPE'] = data_new_17['EXCLTYPE'].str.strip()

# %%
data_new_17['EXCLTYPE'].unique()
# Out:
# array(['1128b4', '1128a4', '1128a1', '1128b5', 'BRCH CIA', '1128b7',
#        '1128b6', '1128b14', '1128a3', '1128b3', '1128a2', 'BRCH SA'], dtype=object)

# %%
data_new_17 = data_new_17[sorted(data_new_17.columns)]

# %%
data_new_17
# Out:
#                             ADDRESS  AVERAGE_MEDICARE_ALLOWED_AMT  \
# 0                863 LARKFIELD ROAD                     84.290000
# 1                863 LARKFIELD ROAD                    123.460000
# 2           P O BOX 6000 #43665-013                     73.160000
# 3           P O BOX 6000 #43665-013                    107.550000
# 4           P O BOX 6000 #43665-013                     42.230000
# 5           P O BOX 6000 #43665-013                     26.150000
# 6           P O BOX 6000 #43665-013                    116.480000
# 7                     P O BOX 12843                    301.240000
# 8                     P O BOX 12843                    149.420000
# 9                     P O BOX 12843                    150.000000
# 10                    P O BOX 12843                    278.190000
# 11                    P O BOX 12843                    138.030000
# 12                    P O BOX 12843                    138.620000
# ...

# %%
# identify individuals granted waivers to keep their license

# %%
data_new_17.query('NPI == 1285673012 or NPI == 1871571406')
# Out:
#                   ADDRESS  AVERAGE_MEDICARE_ALLOWED_AMT  \
# 425     8306 ESTATE DRIVE                    158.900000
# 426     8306 ESTATE DRIVE                    659.620000
# 427     8306 ESTATE DRIVE                     64.258640
# 428     8306 ESTATE DRIVE                     17.737423
# 429     8306 ESTATE DRIVE                     28.838973
# 430     8306 ESTATE DRIVE                     24.004561
# 431     8306 ESTATE DRIVE                     54.264066
# 432     8306 ESTATE DRIVE                     21.220000
# 433     8306 ESTATE DRIVE                     69.035889
# 434     8306 ESTATE DRIVE                     30.643188
# 435     8306 ESTATE DRIVE                    127.639827
# 436     8306 ESTATE DRIVE                     26.608158
# 437     8306 ESTATE DRIVE                    128.630000
# 438     8306 ESTATE DRIVE                     60.547091
# 439     8306 ESTATE DRIVE                     22.954310
# 440     8306 ESTATE DRIVE                    103.061765
# ...

# %%
data_new_17 = data_new_17[(data_new_17.NPI != 1285673012) & (data_new_17.NPI != 1871571406)]

# %%
data_new_17.shape
# Out:
# (1608, 44)

# %%
data_new_17.to_csv('Exclusions_CMS_2017_Match_Labels.csv', index = False)

# %%
# add the businesses to the matched file

# %%
exclusions_business = data_exclusions[data_exclusions['LASTNAME'].isnull()]

# %%
# exclsuions_business = exclusions_business.dropna(how = 'any', subset = ['BUSNAME'])

# %%
exclusions_business = exclusions_business[exclusions_business['BUSNAME'].notnull()]

# %%
exclusions_business = exclusions_business[(exclusions_business.NPI == 0)]

# %%
exclusions_business.rename(columns = {'BUSNAME':'NPPES_PROVIDER_LAST_ORG_NAME'}, inplace = True)

# %%
exclusions_business.dtypes
# Out:
# LASTNAME                         object
# FIRSTNAME                        object
# MIDNAME                          object
# NPPES_PROVIDER_LAST_ORG_NAME     object
# GENERAL                          object
# SPECIALTY                        object
# UPIN                             object
# NPI                               int64
# DOB                             float64
# ADDRESS                          object
# CITY                             object
# STATE                            object
# ZIP                               int64
# EXCLTYPE                         object
# EXCLDATE                          int64
# REINDATE                          int64
# WAIVERDATE                        int64
# WVRSTATE                         object
# dtype: object

# %%
exclusions_business
# Out:
#      LASTNAME FIRSTNAME MIDNAME                         BUSNAME  \
# 0         NaN       NaN                14 LAWRENCE AVE PHARMACY
# 1         NaN       NaN                143 MEDICAL EQUIPMENT CO
# 3         NaN       NaN           1951 FLATBUSH AVENUE PHARMACY
# 4         NaN       NaN           1ST COMMUNITY HEALTH CTR, LTD
# 5         NaN       NaN           1ST REHABILITATION OF PORT ST
# 6         NaN       NaN           2001 BATH AVENUE PHARMACY INC
# 7         NaN       NaN                      2258 PHARMACY, INC
# 8         NaN       NaN          227 NINTH AVENUE PHARMACY, INC
# 9         NaN       NaN                     3839 PHARMACY, INC.
# 10        NaN       NaN                         54-26 DRUG CORP
# 11        NaN       NaN                 716 TRANSPORTATION, INC
# 12        NaN       NaN           764 FRANKLIN AVE PHARMACY INC
# 13        NaN       NaN            882 E 180TH STREET DRUG CORP
# 14        NaN       NaN                       A & A LIVERY, INC
# ...

# %%
data_business_17 = pd.merge(data_NPI_17, exclusions_business, on='NPPES_PROVIDER_LAST_ORG_NAME', how='inner')

# %%
data_business_17
# Out:
#          NPI_x NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 0   1033505433          BELLEVILLE PHARMACY                       NaN
# 1   1033505433          BELLEVILLE PHARMACY                       NaN
# 2   1033505433          BELLEVILLE PHARMACY                       NaN
# 3   1063705408            CORNER DRUG STORE                       NaN
# 4   1063705408            CORNER DRUG STORE                       NaN
# 5   1063705408            CORNER DRUG STORE                       NaN
# 6   1184063695      ELITE AMBULANCE SERVICE                       NaN
# 7   1184063695      ELITE AMBULANCE SERVICE                       NaN
# 8   1184063695      ELITE AMBULANCE SERVICE                       NaN
# 9   1184063695      ELITE AMBULANCE SERVICE                       NaN
# 10  1184063695      ELITE AMBULANCE SERVICE                       NaN
# 11  1528507985                       MEDICO                     AMBER
# ...

# %%
data_business_17.dtypes
# Out:
# NPI_x                                 int64
# NPPES_PROVIDER_LAST_ORG_NAME         object
# NPPES_PROVIDER_FIRST_NAME            object
# NPPES_PROVIDER_MI                    object
# NPPES_CREDENTIALS                    object
# NPPES_PROVIDER_GENDER                object
# NPPES_ENTITY_CODE                    object
# NPPES_PROVIDER_STREET1               object
# NPPES_PROVIDER_STREET2               object
# NPPES_PROVIDER_CITY                  object
# NPPES_PROVIDER_ZIP                   object
# NPPES_PROVIDER_STATE                 object
# NPPES_PROVIDER_COUNTRY               object
# PROVIDER_TYPE                        object
# MEDICARE_PARTICIPATION_INDICATOR     object
# PLACE_OF_SERVICE                     object
# HCPCS_CODE                           object
# HCPCS_DESCRIPTION                    object
# HCPCS_DRUG_INDICATOR                 object
# LINE_SRVC_CNT                       float64
# BENE_UNIQUE_CNT                     float64
# ...

# %%
data_business_17['BUSNAME'] = data_business_17['NPPES_PROVIDER_LAST_ORG_NAME']

# %%
data_business_17.drop('NPI_y', axis=1, inplace=True)

# %%
data_business_17.rename(columns = {'NPI_x':'NPI'}, inplace = True)

# %%
data_business_17.dtypes
# Out:
# NPI                                   int64
# NPPES_PROVIDER_LAST_ORG_NAME         object
# NPPES_PROVIDER_FIRST_NAME            object
# NPPES_PROVIDER_MI                    object
# NPPES_CREDENTIALS                    object
# NPPES_PROVIDER_GENDER                object
# NPPES_ENTITY_CODE                    object
# NPPES_PROVIDER_STREET1               object
# NPPES_PROVIDER_STREET2               object
# NPPES_PROVIDER_CITY                  object
# NPPES_PROVIDER_ZIP                   object
# NPPES_PROVIDER_STATE                 object
# NPPES_PROVIDER_COUNTRY               object
# PROVIDER_TYPE                        object
# MEDICARE_PARTICIPATION_INDICATOR     object
# PLACE_OF_SERVICE                     object
# HCPCS_CODE                           object
# HCPCS_DESCRIPTION                    object
# HCPCS_DRUG_INDICATOR                 object
# LINE_SRVC_CNT                       float64
# BENE_UNIQUE_CNT                     float64
# ...

# %%
data_business_17.shape
# Out:
# (18, 43)

# %%
data_business_17['NPPES_PROVIDER_ZIP'] = data_business_17.NPPES_PROVIDER_ZIP.astype(str)

# %%
data_business_17['NPPES_PROVIDER_ZIP'] = data_business_17['NPPES_PROVIDER_ZIP'].str[:5]

# %%
data_business_17['EXCLDATE'] = data_business_17.EXCLDATE.astype(str)

# %%
data_business_17['EXCLDATE'] = pd.to_datetime(data_business_17['EXCLDATE'], format = "%Y/%m/%d")

# %%
data_business_17['EXCLYEAR'] = data_business_17['EXCLDATE'].dt.year

# %%
data_business_17['EXCLYEAR'] = data_business_17.EXCLYEAR.astype(str)

# %%
data_business_17['DOB'] = data_business_17.DOB.astype(str)

# %%
data_business_17['DOB'] = data_business_17['DOB'].str.strip('.0')

# %%
data_business_17['DOB'] = pd.to_datetime(data_business_17['DOB'], format = "%Y/%m/%d", errors = 'coerce')

# %%
data_business_17['ZIP'] = data_business_17.ZIP.astype(str)

# %%
data_business_17['EXCLTYPE'] = data_business_17['EXCLTYPE'].str.strip()

# %%
data_business_17['EXCLTYPE'].unique()
# Out:
# array(['1128b5', '1128a1', '1128b8'], dtype=object)

# %%
data_business_17 = data_business_17[sorted(data_business_17.columns)]

# %%
data_business_17.dtypes
# Out:
# ADDRESS                                     object
# AVERAGE_MEDICARE_ALLOWED_AMT               float64
# AVERAGE_MEDICARE_PAYMENT_AMT               float64
# AVERAGE_MEDICARE_STANDARD_AMT              float64
# AVERAGE_SUBMITTED_CHRG_AMT                 float64
# BENE_DAY_SRVC_CNT                          float64
# BENE_UNIQUE_CNT                            float64
# BUSNAME                                     object
# CITY                                        object
# DOB                                 datetime64[ns]
# EXCLDATE                            datetime64[ns]
# EXCLTYPE                                    object
# EXCLYEAR                                    object
# FIRSTNAME                                   object
# GENERAL                                     object
# HCPCS_CODE                                  object
# HCPCS_DESCRIPTION                           object
# HCPCS_DRUG_INDICATOR                        object
# ...

# %%
data_business_17
# Out:
#                       ADDRESS  AVERAGE_MEDICARE_ALLOWED_AMT  \
# 0            4002 WESTERN AVE                     48.241250
# 1            4002 WESTERN AVE                     20.951111
# 2            4002 WESTERN AVE                     28.096154
# 3       109 HICKORY HOLLOW DR                     19.030000
# 4       109 HICKORY HOLLOW DR                     23.720000
# 5       109 HICKORY HOLLOW DR                     23.720000
# 6           163 S 10TH STREET                      6.881711
# 7           163 S 10TH STREET                    256.470000
# 8           163 S 10TH STREET                    406.070000
# 9           163 S 10TH STREET                    197.308105
# 10          163 S 10TH STREET                    342.012222
# 11        2810 WENTWOOD DRIVE                     58.960000
# 12  228 CHESTERFIELD INDUST B                     45.753913
# 13  228 CHESTERFIELD INDUST B                    192.640000
# 14  228 CHESTERFIELD INDUST B                     17.840000
# ...

# %%
frames2 = [data_business_17, data_new_17]

# %%
common_cols = list(set.intersection(*(set(df.columns) for df in frames2)))

# %%
data_business_17 = pd.concat([df[common_cols] for df in frames2], ignore_index=True)

# %%
data_business_17
# Out:
#                 CITY  AVERAGE_MEDICARE_PAYMENT_AMT    ZIP STATE  \
# 0         SOUTH BEND                     47.277500  46619    IN
# 1         SOUTH BEND                     20.533333  46619    IN
# 2         SOUTH BEND                     27.536154  46619    IN
# 3          OAK RIDGE                     18.650000  37830    TN
# 4          OAK RIDGE                     23.250000  37830    TN
# 5          OAK RIDGE                     23.250000  37830    TN
# 6            SUNBURY                      5.385266  17801    PA
# 7            SUNBURY                    191.542391  17801    PA
# 8            SUNBURY                    289.418182  17801    PA
# 9            SUNBURY                    154.245662  17801    PA
# 10           SUNBURY                    268.138704  17801    PA
# 11         GRAPEVINE                     36.894118  76051    TX
# 12      CHESTERFIELD                     44.840870  63005    MO
# 13      CHESTERFIELD                    188.790000  63005    MO
# ...

# %%
data_business_17 = data_business_17[sorted(data_business_17.columns)]

# %%
data_business_17.to_csv('Exclusions_CMS_2017_Match_Labels.csv', index = False)

# %%
# the following code is combined for all years
exclusions_NPI['NPPES_PROVIDER_ZIP'] = exclusions_NPI.NPPES_PROVIDER_ZIP.astype(str)

# %%
exclusions_NPI['NPPES_PROVIDER_ZIP'] = exclusions_NPI['NPPES_PROVIDER_ZIP'].str[:5]

# %%
exclusions_NPI['EXCLDATE'] = exclusions_NPI.EXCLDATE.astype(str)

# %%
exclusions_NPI['EXCLDATE'] = pd.to_datetime(exclusions_NPI['EXCLDATE'], format = "%Y/%m/%d")

# %%
exclusions_NPI['EXCLYEAR'] = exclusions_NPI['EXCLDATE'].dt.year

# %%
exclusions_NPI['EXCLYEAR'] = exclusions_NPI.EXCLYEAR.astype(str)

# %%
exclusions_NPI['DOB'] = exclusions_NPI.DOB.astype(str)

# %%
exclusions_NPI['DOB'] = exclusions_NPI['DOB'].str.strip('.0')

# %%
exclusions_NPI['DOB'] = pd.to_datetime(exclusions_NPI['DOB'], format = "%Y/%m/%d", errors = 'coerce')

# %%
exclusions_NPI['ZIP'] = exclusions_NPI.ZIP.astype(str)

# %%
exclusions_NPI['EXCLTYPE'] = exclusions_NPI['EXCLTYPE'].str.strip()

# %%
exclusions_NPI.shape
# Out:
# (49323, 43)

# %%
exclusions_NPI.dtypes
# Out:
# ADDRESS                                     object
# AVERAGE_MEDICARE_ALLOWED_AMT               float64
# AVERAGE_MEDICARE_PAYMENT_AMT               float64
# AVERAGE_SUBMITTED_CHRG_AMT                 float64
# BENE_DAY_SRVC_CNT                          float64
# BENE_UNIQUE_CNT                            float64
# BUSNAME                                     object
# CITY                                        object
# DOB                                 datetime64[ns]
# EXCLDATE                            datetime64[ns]
# EXCLTYPE                                    object
# FIRSTNAME                                   object
# GENERAL                                     object
# HCPCS_CODE                                  object
# HCPCS_DESCRIPTION                           object
# HCPCS_DRUG_INDICATOR                        object
# LASTNAME                                    object
# LINE_SRVC_CNT                              float64
# ...

# %%
exclusions_NPI['NPI'].nunique()
# Out:
# 1322

# %%
data_new_17['NPI'].nunique()
# Out:
# 165

# %%
data_new_16['NPI'].nunique()
# Out:
# 347

# %%
data_new_15['NPI'].nunique()
# Out:
# 553

# %%
data_new_14['NPI'].nunique()
# Out:
# 780

# %%
data_new_13['NPI'].nunique()
# Out:
# 991

# %%
data_new_12['NPI'].nunique()
# Out:
# 1220

# %%
# test
exclusions_NPI.loc[exclusions_NPI['NPI'] == 1982782900]
# Out:
# Empty DataFrame
# Columns: [ADDRESS, AVERAGE_MEDICARE_ALLOWED_AMT, AVERAGE_MEDICARE_PAYMENT_AMT, AVERAGE_SUBMITTED_CHRG_AMT, BENE_DAY_SRVC_CNT, BENE_UNIQUE_CNT, BUSNAME, CITY, DOB, EXCLDATE, EXCLTYPE, FIRSTNAME, GENERAL, HCPCS_CODE, HCPCS_DESCRIPTION, HCPCS_DRUG_INDICATOR, LASTNAME, LINE_SRVC_CNT, MEDICARE_PARTICIPATION_INDICATOR, MIDNAME, NPI, NPPES_CREDENTIALS, NPPES_ENTITY_CODE, NPPES_PROVIDER_CITY, NPPES_PROVIDER_COUNTRY, NPPES_PROVIDER_FIRST_NAME, NPPES_PROVIDER_GENDER, NPPES_PROVIDER_LAST_ORG_NAME, NPPES_PROVIDER_MI, NPPES_PROVIDER_STATE, NPPES_PROVIDER_STREET1, NPPES_PROVIDER_STREET2, NPPES_PROVIDER_ZIP, PLACE_OF_SERVICE, PROVIDER_TYPE, REINDATE, SPECIALTY, STATE, UPIN, WAIVERDATE, WVRSTATE, ZIP]
# Index: []
#
# [0 rows x 42 columns]

# %%
exclusions_samp = exclusions_NPI[['NPI', 'EXCLDATE']]

# %%
exclusions_samp
# Out:
#               NPI  EXCLDATE
# 0      1003811167  20171220
# 1      1003811167  20171220
# 2      1003892746  20180419
# 3      1003892746  20180419
# 4      1003892746  20180419
# 5      1003892746  20180419
# 6      1003892746  20180419
# 7      1003904830  20171120
# 8      1003904830  20171120
# 9      1003904830  20171120
# 10     1003904830  20171120
# 11     1003904830  20171120
# 12     1003904830  20171120
# 13     1003904830  20171120
# 14     1003904830  20171120
# 15     1003904830  20171120
# 16     1003904830  20171120
# 17     1003904830  20171120
# 18     1003904830  20171120
# 19     1003904830  20171120
# 20     1003904830  20171120
# 21     1013009729  20180419
# 22     1013009729  20180419
# 23     1013009729  20180419
# 24     1013009729  20180419
# 25     1013009729  20180419
# 26     1013009729  20180419
# 27     1013095975  20190120
# 28     1013095975  20190120
# 29     1013095975  20190120
# ...           ...       ...
# 49293  1992701544  20180320
# ...

# %%
exclusions_samp['EXCLDATE'].unique()
# note: if someone got excluded prior to 2012, but then subsequently received a waiver, they appear here in this list; here,
# we can see one exclusion date, 2009, appears on this list of CMS service providers from 2012 through 2017; this list does not
# identify exclusions that were made during 2012 through 2017 and that got subsequent re-instatements during that period
# Out:
# array([20171220, 20180419, 20171120, 20190120, 20181120, 20170620,
#        20190520, 20190403, 20180520, 20180220, 20181220, 20180920,
#        20190418, 20180720, 20170820, 20170113, 20190718, 20190220,
#        20190620, 20180320, 20180620, 20171019, 20171204, 20180817,
#        20150618, 20180118, 20190712, 20190320, 20181130, 20190528,
#        20180820, 20170515, 20190820, 20171024, 20170911, 20170908,
#        20190708, 20180719, 20170920, 20170922, 20170720, 20180914,
#        20180824, 20181113, 20170313, 20160120, 20170119, 20181018,
#        20170220, 20161020, 20170320, 20091220, 20180808, 20161220,
#        20160818, 20160519, 20160518, 20180619, 20170420, 20170518,
#        20161120, 20160320, 20170126, 20170101, 20160901, 20161209,
#        20170517, 20160920, 20170201, 20150901, 20110720, 20160620,
#        20160208, 20150820, 20150720, 20160218, 20160505, 20190507,
#        20151020, 20150415, 20160928, 20160420, 20151220, 20160711,
# ...

# %%
exclusions_samp.groupby('EXCLDATE')['NPI'].nunique()
# Out:
# EXCLDATE
# 20091220     1
# 20110720     1
# 20120301     1
# 20120520     1
# 20120619     1
# 20120719     2
# 20120820     3
# 20120920     2
# 20121018     2
# 20121114     1
# 20121220     1
# 20130120     5
# 20130220     4
# 20130320     1
# 20130417     1
# 20130418     4
# 20130520     1
# 20130620     5
# 20130628     1
# 20130718     1
# 20130820    12
# 20130919     5
# 20131020     6
# 20131120     6
# 20131219    11
# 20140120     8
# 20140220     6
# 20140313     1
# 20140320     4
# 20140411     1
#             ..
# 20180520    16
# 20180619     1
# 20180620    17
# 20180719     8
# 20180720     1
# 20180808     1
# 20180817     1
# 20180820    20
# 20180824     1
# 20180914     2
# 20180920    27
# 20181001     1
# 20181018     9
# 20181113     1
# 20181120    21
# 20181130     1
# 20181220    16
# 20190120    12
# 20190220    10
# 20190320    14
# 20190403     1
# 20190418    30
# 20190507     1
# 20190520    20
# 20190528     1
# 20190620    33
# 20190708     2
# ...

# %%
print(exclusions_samp.dtypes)
# Out:
# NPI         int64
# EXCLDATE    int64
# dtype: object

# %%
exclusions_samp['EXCLDATE'] = exclusions_samp.EXCLDATE.astype(str)
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
exclusions_samp['EXCLYEAR'] = exclusions_samp['EXCLDATE'].str[:4]
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
exclusions_samp
# Out:
#               NPI  EXCLDATE EXCLYEAR
# 0      1003811167  20171220     2017
# 1      1003811167  20171220     2017
# 2      1003892746  20180419     2018
# 3      1003892746  20180419     2018
# 4      1003892746  20180419     2018
# 5      1003892746  20180419     2018
# 6      1003892746  20180419     2018
# 7      1003904830  20171120     2017
# 8      1003904830  20171120     2017
# 9      1003904830  20171120     2017
# 10     1003904830  20171120     2017
# 11     1003904830  20171120     2017
# 12     1003904830  20171120     2017
# 13     1003904830  20171120     2017
# 14     1003904830  20171120     2017
# 15     1003904830  20171120     2017
# 16     1003904830  20171120     2017
# 17     1003904830  20171120     2017
# 18     1003904830  20171120     2017
# 19     1003904830  20171120     2017
# 20     1003904830  20171120     2017
# 21     1013009729  20180419     2018
# 22     1013009729  20180419     2018
# 23     1013009729  20180419     2018
# ...

# %%
exclusions_samp['EXCLYEAR'] = exclusions_samp.EXCLYEAR.astype(int)
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
exclusions_samp.dtypes
# Out:
# NPI          int64
# EXCLDATE    object
# EXCLYEAR     int32
# dtype: object

# %%
count = exclusions_samp.groupby('EXCLYEAR')['NPI'].nunique()

# %%
count
# Out:
# EXCLYEAR
# 2009      1
# 2011      1
# 2012     14
# 2013     63
# 2014    145
# 2015    201
# 2016    246
# 2017    316
# 2018    220
# 2019    147
# Name: NPI, dtype: int64

# %%
count.dtypes
# Out:
# dtype('int64')

# %%
exclusions_samp.dtypes
# Out:
# NPI          int64
# EXCLDATE    object
# EXCLYEAR     int32
# dtype: object

# %%
table_plot = count.rename_axis('EXCLYEAR').reset_index(name = 'Counts')

# %%
table_plot
# Out:
#    EXCLYEAR  Counts
# 0      2009       1
# 1      2011       1
# 2      2012      14
# 3      2013      63
# 4      2014     145
# 5      2015     201
# 6      2016     246
# 7      2017     316
# 8      2018     220
# 9      2019     147

# %%
table_plot.plot.bar('EXCLYEAR', color = 'darkmagenta')

# %%
count2 = exclusions_samp.groupby('NPI')['EXCLYEAR'].nunique()

# %%
count2 # some NPIs have more than one exclusion that have occurred between 2012 through 2017
# Out:
# NPI
# 1003042441    1
# 1003809195    1
# 1003811167    1
# 1003817743    1
# 1003838087    1
# 1003854159    1
# 1003859885    1
# 1003878711    1
# 1003885344    1
# 1003886979    1
# 1003892746    1
# 1003902800    1
# 1003904830    1
# 1003908799    1
# 1003972670    1
# 1003999376    1
# 1013009000    1
# 1013009729    1
# 1013038629    1
# 1013056670    1
# 1013059740    2
# 1013063064    1
# 1013093178    1
# 1013095975    1
# 1013097708    1
# 1013115914    1
# 1013167311    1
# 1013297258    1
# 1013957182    1
# 1013998640    1
#              ..
# 1972687754    1
# 1972694677    1
# 1972791820    1
# 1972839447    1
# 1982601704    1
# 1982602389    1
# 1982602686    1
# 1982603890    1
# 1982607370    1
# 1982609723    1
# 1982637856    1
# 1982646089    1
# 1982661385    1
# 1982679544    1
# 1982706941    1
# 1982714796    1
# 1982753653    1
# 1982779799    1
# 1982781506    1
# 1982881587    1
# 1992030050    1
# 1992034250    1
# 1992701544    1
# 1992717250    1
# ...

# %%
exclusions_samp2 = exclusions_NPI[['NPI', 'EXCLTYPE']]

# %%
exclusions_type = exclusions_samp2.groupby('EXCLTYPE')['NPI'].nunique()

# %%
exclusions_type
# Out:
# EXCLTYPE
# 1128Aa         1
# 1128a1       328
# 1128a1       137
# 1128a2        58
# 1128a2         2
# 1128a3        61
# 1128a3         8
# 1128a4       201
# 1128b1         7
# 1128b14       22
# 1128b16        1
# 1128b2         2
# 1128b3         9
# 1128b4       445
# 1128b5        19
# 1128b6         4
# 1128b6         1
# 1128b7        39
# 1128b7         1
# 1128b8         2
# 1156           2
# BRCH CIA       2
# BRCH SA        2
# Name: NPI, dtype: int64

# %%
exclusions_type2 = exclusions_samp2['EXCLTYPE'].unique()

# %%
# note the output; the below types need data cleaning to remove trailing spaces
exclusions_type2
# Out:
# array(['1128b4', '1128a4', '1128a1', '1128a1   ', '1128b5', 'BRCH CIA',
#        '1128b7', '1128b6', '1128b14', '1128a3', '1128b3', '1128a3   ',
#        '1128a2', 'BRCH SA', '1128a2   ', '1128b8', '1128b1', '1156',
#        '1128Aa', '1128b16', '1128b6   ', '1128b2', '1128b7   '], dtype=object)

# %%
# codes that will be included in analysis
# 1128a1, 1128a3, 1128b1, 1128b5, 1128b7

# %%
exclusions_samp2.dtypes
# Out:
# NPI          int64
# EXCLTYPE    object
# dtype: object
