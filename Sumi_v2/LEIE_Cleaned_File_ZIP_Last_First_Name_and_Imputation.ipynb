# %%
import pandas as pd
from datetime import date
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import colors
import seaborn as sns

# %%
hcpcs10 = pd.read_csv('top10_hcpcs.csv')
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
hcpcs10.columns = hcpcs10.columns.str.upper()

# %%
hcpcs10['NPPES_PROVIDER_ZIP'] = hcpcs10.NPPES_PROVIDER_ZIP.astype(str)

# %%
hcpcs10['PROV_ZIP'] = hcpcs10.NPPES_PROVIDER_ZIP.str.slice(0,5,1)

# %%
leie_m = pd.read_csv('LEIE_Database.csv', dtype={'ZIP': object})
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
leie_m['zip_len']=leie_m['ZIP'].str.len()

# %%
leie_m['zip_len'].value_counts()
# Out:
# 5    72473
# 4        3
# Name: zip_len, dtype: int64

# %%
leie_m['zip_new']= leie_m['ZIP'].apply(lambda x: x.zfill(5))

# %%
leie_m.dtypes
# Out:
# LASTNAME       object
# FIRSTNAME      object
# MIDNAME        object
# BUSNAME        object
# GENERAL        object
# SPECIALTY      object
# UPIN           object
# NPI             int64
# DOB           float64
# ADDRESS        object
# CITY           object
# STATE          object
# ZIP            object
# EXCLTYPE       object
# EXCLDATE        int64
# REINDATE        int64
# WAIVERDATE      int64
# WVRSTATE       object
# zip_len         int64
# zip_new        object
# dtype: object

# %%
leie_m.head()
# Out:
#   LASTNAME FIRSTNAME MIDNAME                        BUSNAME         GENERAL  \
# 0      NaN       NaN               14 LAWRENCE AVE PHARMACY        PHARMACY
# 1      NaN       NaN               143 MEDICAL EQUIPMENT CO     DME COMPANY
# 2      NaN       NaN             184TH STREET PHARMACY CORP  OTHER BUSINESS
# 3      NaN       NaN          1951 FLATBUSH AVENUE PHARMACY        PHARMACY
# 4      NaN       NaN          1ST COMMUNITY HEALTH CTR, LTD          CLINIC
#
#       SPECIALTY UPIN         NPI  DOB             ADDRESS       CITY STATE  \
# 0           NaN  NaN           0  NaN  14 LAWRENCE AVENUE  SMITHTOWN    NY
# 1  DME - OXYGEN  NaN           0  NaN    701 NW 36 AVENUE      MIAMI    FL
# 2      PHARMACY  NaN  1922348218  NaN       69 E 184TH ST      BRONX    NY
# 3           NaN  NaN           0  NaN   1951 FLATBUSH AVE   BROOKLYN    NY
# 4           NaN  NaN           0  NaN  3138 W CERMAK ROAD    CHICAGO    IL
#
# ...

# %%
leie_m.shape
# Out:
# (72476, 20)

# %%
leie_m.columns.tolist()
# Out:
# ['LASTNAME',
#  'FIRSTNAME',
#  'MIDNAME',
#  'BUSNAME',
#  'GENERAL',
#  'SPECIALTY',
#  'UPIN',
#  'NPI',
#  'DOB',
#  'ADDRESS',
#  'CITY',
#  'STATE',
#  'ZIP',
#  'EXCLTYPE',
#  'EXCLDATE',
#  'REINDATE',
#  'WAIVERDATE',
#  'WVRSTATE',
#  'zip_len',
#  'zip_new']

# %%
leie_m.columns = leie_m.columns.str.upper()

# %%
leie_m['zip_len']=leie_m['ZIP_NEW'].str.len()

# %%
leie_m['zip_len'].value_counts()
# Out:
# 5    72476
# Name: zip_len, dtype: int64

# %%
leie_m.head()
# Out:
#   LASTNAME FIRSTNAME MIDNAME                        BUSNAME         GENERAL  \
# 0      NaN       NaN               14 LAWRENCE AVE PHARMACY        PHARMACY
# 1      NaN       NaN               143 MEDICAL EQUIPMENT CO     DME COMPANY
# 2      NaN       NaN             184TH STREET PHARMACY CORP  OTHER BUSINESS
# 3      NaN       NaN          1951 FLATBUSH AVENUE PHARMACY        PHARMACY
# 4      NaN       NaN          1ST COMMUNITY HEALTH CTR, LTD          CLINIC
#
#       SPECIALTY UPIN         NPI  DOB             ADDRESS   ...   STATE  \
# 0           NaN  NaN           0  NaN  14 LAWRENCE AVENUE   ...      NY
# 1  DME - OXYGEN  NaN           0  NaN    701 NW 36 AVENUE   ...      FL
# 2      PHARMACY  NaN  1922348218  NaN       69 E 184TH ST   ...      NY
# 3           NaN  NaN           0  NaN   1951 FLATBUSH AVE   ...      NY
# 4           NaN  NaN           0  NaN  3138 W CERMAK ROAD   ...      IL
#
# ...

# %%
hcpcs10.head()
# Out:
#    UNNAMED: 0         NPI NPPES_PROVIDER_LAST_ORG_NAME  \
# 0           6  1003000126                    ENKESHAFI
# 1           7  1003000126                    ENKESHAFI
# 2           8  1003000126                    ENKESHAFI
# 3          10  1003000126                    ENKESHAFI
# 4          39  1003000142                       KHALIL
#
#   NPPES_PROVIDER_FIRST_NAME NPPES_PROVIDER_MI NPPES_CREDENTIALS  \
# 0                   ARDALAN               NaN              M.D.
# 1                   ARDALAN               NaN              M.D.
# 2                   ARDALAN               NaN              M.D.
# 3                   ARDALAN               NaN              M.D.
# 4                    RASHID               NaN              M.D.
#
#   NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE      NPPES_PROVIDER_STREET1  \
# 0                     M                 I                900 SETON DR
# 1                     M                 I                900 SETON DR
# ...

# %%
hcpcs10.drop(hcpcs10.columns[hcpcs10.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
hcpcs10.head()
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 0  1003000126                    ENKESHAFI                   ARDALAN
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000142                       KHALIL                    RASHID
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 0               NaN              M.D.                     M                 I
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
#
#        NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY  \
# ...

# %%
hcpcs10.dtypes
# Out:
# NPI                                   int64
# NPPES_PROVIDER_LAST_ORG_NAME         object
# NPPES_PROVIDER_FIRST_NAME            object
# NPPES_PROVIDER_MI                    object
# NPPES_CREDENTIALS                    object
# NPPES_PROVIDER_GENDER                object
# NPPES_ENTITY_CODE                    object
# NPPES_PROVIDER_STREET1               object
# NPPES_PROVIDER_STREET2               object
# NPPES_PROVIDER_CITY                  object
# NPPES_PROVIDER_ZIP                   object
# NPPES_PROVIDER_STATE                 object
# NPPES_PROVIDER_COUNTRY               object
# PROVIDER_TYPE                        object
# MEDICARE_PARTICIPATION_INDICATOR     object
# PLACE_OF_SERVICE                     object
# HCPCS_CODE                           object
# HCPCS_DESCRIPTION                    object
# HCPCS_DRUG_INDICATOR                 object
# LINE_SRVC_CNT                       float64
# BENE_UNIQUE_CNT                       int64
# ...

# %%
hcpcs10['zip_len']=hcpcs10['PROV_ZIP'].str.len()

# %%
hcpcs10['zip_len'].value_counts()
# Out:
# 5    1499547
# 4      19361
# 3       2064
# 1         11
# 2          2
# Name: zip_len, dtype: int64

# %%
hcpcs10['zip_new']= hcpcs10['PROV_ZIP'].apply(lambda x: x.zfill(5))

# %%
hcpcs10['zip_len2']=hcpcs10['zip_new'].str.len()

# %%
hcpcs10['zip_len2'].value_counts()
# Out:
# 5    1520985
# Name: zip_len2, dtype: int64

# %%
hcpcs10.columns = hcpcs10.columns.str.upper()

# %%
# regex to remove any non-alphabetic characters
hcpcs10['NPPES_PROVIDER_LAST_ORG_NAME'] = hcpcs10.NPPES_PROVIDER_LAST_ORG_NAME.str.replace('[^a-zA-Z]', '').str.upper()

# %%
hcpcs10.head()
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 0  1003000126                    ENKESHAFI                   ARDALAN
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000142                       KHALIL                    RASHID
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 0               NaN              M.D.                     M                 I
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
#
#        NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY  \
# ...

# %%
hcpcs10['NPPES_PROVIDER_FIRST_NAME'] = hcpcs10.NPPES_PROVIDER_FIRST_NAME.str.replace('[^a-zA-Z]', '').str.upper()

# %%
hcpcs10.head()
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 0  1003000126                    ENKESHAFI                   ARDALAN
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000142                       KHALIL                    RASHID
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 0               NaN              M.D.                     M                 I
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
#
#        NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY  \
# ...

# %%
hcpcs10.shape
# Out:
# (1520985, 32)

# %%
hcpcs10.dtypes
# Out:
# NPI                                   int64
# NPPES_PROVIDER_LAST_ORG_NAME         object
# NPPES_PROVIDER_FIRST_NAME            object
# NPPES_PROVIDER_MI                    object
# NPPES_CREDENTIALS                    object
# NPPES_PROVIDER_GENDER                object
# NPPES_ENTITY_CODE                    object
# NPPES_PROVIDER_STREET1               object
# NPPES_PROVIDER_STREET2               object
# NPPES_PROVIDER_CITY                  object
# NPPES_PROVIDER_ZIP                   object
# NPPES_PROVIDER_STATE                 object
# NPPES_PROVIDER_COUNTRY               object
# PROVIDER_TYPE                        object
# MEDICARE_PARTICIPATION_INDICATOR     object
# PLACE_OF_SERVICE                     object
# HCPCS_CODE                           object
# HCPCS_DESCRIPTION                    object
# HCPCS_DRUG_INDICATOR                 object
# LINE_SRVC_CNT                       float64
# BENE_UNIQUE_CNT                       int64
# ...

# %%
hcpcs10 = hcpcs10.drop(['ZIP_LEN', 'ZIP_LEN2'], axis = 1)

# %%
hcpcs10.head()
# Out:
#           NPI NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# 0  1003000126                    ENKESHAFI                   ARDALAN
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000142                       KHALIL                    RASHID
#
#   NPPES_PROVIDER_MI NPPES_CREDENTIALS NPPES_PROVIDER_GENDER NPPES_ENTITY_CODE  \
# 0               NaN              M.D.                     M                 I
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
#
#        NPPES_PROVIDER_STREET1 NPPES_PROVIDER_STREET2 NPPES_PROVIDER_CITY  \
# ...

# %%
hcpcs10.shape
# Out:
# (1520985, 30)

# %%
hcpcs10_ind = hcpcs10[hcpcs10['NPPES_ENTITY_CODE']=='I']

# %%
hcpcs10_ind['NPPES_ENTITY_CODE'].value_counts()
# Out:
# I    1511939
# Name: NPPES_ENTITY_CODE, dtype: int64

# %%
# regex for LEIE file
leie_m['LASTNAME'] = leie_m.LASTNAME.str.replace('[^a-zA-Z]', '').str.upper()

# %%
leie_m['FIRSTNAME'] = leie_m.LASTNAME.str.replace('[^a-zA-Z]', '').str.upper()

# %%
leie_m.columns = leie_m.columns.str.upper()

# %%
leie_m.head()
# Out:
#   LASTNAME FIRSTNAME MIDNAME                        BUSNAME         GENERAL  \
# 0      NaN       NaN               14 LAWRENCE AVE PHARMACY        PHARMACY
# 1      NaN       NaN               143 MEDICAL EQUIPMENT CO     DME COMPANY
# 2      NaN       NaN             184TH STREET PHARMACY CORP  OTHER BUSINESS
# 3      NaN       NaN          1951 FLATBUSH AVENUE PHARMACY        PHARMACY
# 4      NaN       NaN          1ST COMMUNITY HEALTH CTR, LTD          CLINIC
#
#       SPECIALTY UPIN         NPI  DOB             ADDRESS   ...   STATE  \
# 0           NaN  NaN           0  NaN  14 LAWRENCE AVENUE   ...      NY
# 1  DME - OXYGEN  NaN           0  NaN    701 NW 36 AVENUE   ...      FL
# 2      PHARMACY  NaN  1922348218  NaN       69 E 184TH ST   ...      NY
# 3           NaN  NaN           0  NaN   1951 FLATBUSH AVE   ...      NY
# 4           NaN  NaN           0  NaN  3138 W CERMAK ROAD   ...      IL
#
# ...

# %%
leie_m.shape
# Out:
# (72476, 21)

# %%
leie_m.dtypes
# Out:
# LASTNAME       object
# FIRSTNAME      object
# MIDNAME        object
# BUSNAME        object
# GENERAL        object
# SPECIALTY      object
# UPIN           object
# NPI             int64
# DOB           float64
# ADDRESS        object
# CITY           object
# STATE          object
# ZIP            object
# EXCLTYPE       object
# EXCLDATE        int64
# REINDATE        int64
# WAIVERDATE      int64
# WVRSTATE       object
# ZIP_LEN         int64
# ZIP_NEW        object
# ZIP_LEN         int64
# dtype: object

# %%
leie_m = leie_m.drop(['ZIP_LEN', 'ZIP_LEN'], axis = 1)

# %%
leie_m.head()
# Out:
#   LASTNAME FIRSTNAME MIDNAME                        BUSNAME         GENERAL  \
# 0      NaN       NaN               14 LAWRENCE AVE PHARMACY        PHARMACY
# 1      NaN       NaN               143 MEDICAL EQUIPMENT CO     DME COMPANY
# 2      NaN       NaN             184TH STREET PHARMACY CORP  OTHER BUSINESS
# 3      NaN       NaN          1951 FLATBUSH AVENUE PHARMACY        PHARMACY
# 4      NaN       NaN          1ST COMMUNITY HEALTH CTR, LTD          CLINIC
#
#       SPECIALTY UPIN         NPI  DOB             ADDRESS       CITY STATE  \
# 0           NaN  NaN           0  NaN  14 LAWRENCE AVENUE  SMITHTOWN    NY
# 1  DME - OXYGEN  NaN           0  NaN    701 NW 36 AVENUE      MIAMI    FL
# 2      PHARMACY  NaN  1922348218  NaN       69 E 184TH ST      BRONX    NY
# 3           NaN  NaN           0  NaN   1951 FLATBUSH AVE   BROOKLYN    NY
# 4           NaN  NaN           0  NaN  3138 W CERMAK ROAD    CHICAGO    IL
#
# ...

# %%
leie_m.shape
# Out:
# (72476, 19)

# %%
leie_m['DOB'] = leie_m.DOB.astype(str)

# %%
leie_m['DOB'] = leie_m['DOB'].str.strip('.0')

# %%
leie_m['DOB'] = pd.to_datetime(leie_m['DOB'], format = "%Y/%m/%d", errors = 'coerce')

# %%
leie_m['EXCLTYPE'] = leie_m['EXCLTYPE'].str.strip()

# %%
leie_m['EXCLTYPE'].unique()
# Out:
# array(['1128a1', '1128b7', '1128b5', '1128b8', '1128b4', '1128b6',
#        '1128b1', '1128b2', '1128Aa', '1128a3', '1128a2', '1128a4',
#        '1128b11', 'BRCH CIA', 'BRCH SA', '1160', '1128b3', '1128b16',
#        '1128b14', '1128b15', '1156', '1128b12'], dtype=object)

# %%
leie_m['EXCLDATE'] = leie_m.EXCLDATE.astype(str)

# %%
leie_m['EXCLDATE'] = pd.to_datetime(leie_m['EXCLDATE'], format = "%Y/%m/%d")

# %%
leie_m['EXCLMONTH'] = leie_m['EXCLDATE'].dt.month

# %%
leie_m['EXCLYEAR'] = leie_m['EXCLDATE'].dt.year

# %%
leie_m.dtypes
# Out:
# LASTNAME              object
# FIRSTNAME             object
# MIDNAME               object
# BUSNAME               object
# GENERAL               object
# SPECIALTY             object
# UPIN                  object
# NPI                    int64
# DOB           datetime64[ns]
# ADDRESS               object
# CITY                  object
# STATE                 object
# ZIP                   object
# EXCLTYPE              object
# EXCLDATE      datetime64[ns]
# REINDATE               int64
# WAIVERDATE             int64
# WVRSTATE              object
# ZIP_NEW               object
# EXCLMONTH              int64
# EXCLYEAR               int64
# dtype: object

# %%
leie_m.shape
# Out:
# (72476, 21)

# %%
leie_m.isnull().sum()
# Out:
# LASTNAME       3111
# FIRSTNAME      3111
# MIDNAME           0
# BUSNAME       69368
# GENERAL           0
# SPECIALTY      4200
# UPIN          66143
# NPI               0
# DOB           10600
# ADDRESS           9
# CITY              1
# STATE             5
# ZIP               0
# EXCLTYPE          0
# EXCLDATE          0
# REINDATE          0
# WAIVERDATE        0
# WVRSTATE      72463
# ZIP_NEW           0
# EXCLMONTH         0
# EXCLYEAR          0
# dtype: int64

# %%
(leie_m['NPI'] == 0).sum()
# Out:
# 67207

# %%
# find the individual practitioners; excluding businesses
leie_ind = leie_m[leie_m['LASTNAME'].notnull()]

# %%
# find case with available NPIs
leie_NPI = leie_ind[(leie_ind.NPI != 0)]

# %%
leie_NPI.shape
# Out:
# (4933, 21)

# %%
leie_NPI_unique = leie_NPI.drop_duplicates(subset = 'NPI', keep = 'first')

# %%
leie_NPI_unique.shape
# Out:
# (4835, 21)

# %%
# from Radhika's LEIE file python script => Radhika's file has unique NPIs for individuals and businesses combined; below is
# for individuals only
# LEIE_uniquenpi = leie_NPI.drop_duplicates(subset='NPI')

# %%
# Radhika's file returns 5169 unique NPIs in total
# LEIE_uniquenpi.shape

# %%
leie_NPI_subset = leie_NPI_unique[['NPI', 'GENERAL', 'SPECIALTY', 'EXCLDATE', 'EXCLMONTH', 'EXCLYEAR', 'EXCLTYPE']]

# %%
leie_NPI_subset
# Out:
#               NPI               GENERAL             SPECIALTY   EXCLDATE  \
# 3123   1477537496    PHYSICIAN (MD, DO)     INTERNAL MEDICINE 2014-05-20
# 3142   1194807255    PHYSICIAN (MD, DO)      GENERAL PRACTICE 2018-06-20
# 3143   1225029184    PHYSICIAN (MD, DO)     INTERNAL MEDICINE 2014-04-20
# 3212   1487870507  IND- LIC HC SERV PRO            PHARMACIST 2018-12-20
# 3216   1497811368  MEDICAL PRACTICE, MD               SURGERY 1999-01-20
# 3222   1841203320  IND- LIC HC SERV PRO            PHARMACIST 2014-07-20
# 3228   1003127655    PHYSICIAN (MD, DO)     INTERNAL MEDICINE 2019-09-19
# 3229   1568735264  IND- LIC HC SERV PRO            PHARMACIST 2019-08-20
# 3231   1609874742  MEDICAL PRACTICE, MD               GYN/OBS 2011-06-20
# 3247   1144399403  PSYCHOLOGIC PRACTICE            PSYCHOLOGY 1997-07-07
# 3249   1225369556    PHYSICIAN (MD, DO)      GENERAL PRACTICE 2016-10-20
# 3256   1528114998            LABORATORY        OWNER/OPERATOR 2009-09-20
# ...

# %%
# merge with matched NPIs
hcpcs_NPI_match = pd.merge(hcpcs10_ind, leie_NPI_subset, on=['NPI'], how='left')

# %%
hcpcs_NPI_match.shape
# Out:
# (1511939, 36)

# %%
hcpcs_NPI_match.to_csv('hcpcs_NPI_match.csv', index = False)

# %%
hcpcs_null_EXCLTYPE = hcpcs_NPI_match[hcpcs_NPI_match['EXCLTYPE'].isnull()]

# %%
hcpcs_null_EXCLTYPE.shape
# Out:
# (1511662, 36)

# %%
# set up initial dataframe to impute missing NPI values
leie_NPI_impute = leie_ind[(leie_ind.NPI == 0)]

# %%
leie_NPI_impute.shape
# Out:
# (64432, 21)

# %%
leie_NPI_impute['LAST_ZIP'] = leie_NPI_impute['LASTNAME'] + leie_NPI_impute['ZIP_NEW']
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
hcpcs_null_EXCLTYPE['LAST_ZIP'] = hcpcs_null_EXCLTYPE['NPPES_PROVIDER_LAST_ORG_NAME'] + hcpcs_null_EXCLTYPE['ZIP_NEW']
# Out:
# C:\Users\Sumi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
leie_NPI_impute.isnull().sum()
# Out:
# LASTNAME          0
# FIRSTNAME         0
# MIDNAME           0
# BUSNAME       64432
# GENERAL           0
# SPECIALTY      1862
# UPIN          59585
# NPI               0
# DOB            7036
# ADDRESS           3
# CITY              1
# STATE             4
# ZIP               0
# EXCLTYPE          0
# EXCLDATE          0
# REINDATE          0
# WAIVERDATE        0
# WVRSTATE      64427
# ZIP_NEW           0
# EXCLMONTH         0
# EXCLYEAR          0
# LAST_ZIP          0
# dtype: int64

# %%
# leie_NPI_impute = leie_NPI_impute[leie_NPI_impute['LASTNAME'].notnull()]

# %%
leie_NPI_impute.shape
# Out:
# (64432, 22)

# %%
leie_NPI_impute_unique = leie_NPI_impute.drop_duplicates(subset = 'LAST_ZIP', keep = 'first')

# %%
leie_NPI_impute_unique.shape
# Out:
# (62933, 22)

# %%
hcpcs_NPI_match_impute_last_zip = pd.merge(hcpcs_null_EXCLTYPE, leie_NPI_impute_unique, on=['LAST_ZIP'], how='inner')

# %%
hcpcs_NPI_match_impute_last_zip.shape
# Out:
# (4262, 59)

# %%
unique = hcpcs_NPI_match_impute_last_zip.groupby('LAST_ZIP')['NPI_x'].nunique()

# %%
table = unique.rename_axis('LAST_ZIP').reset_index(name = 'Counts')

# %%
table.head(5)
# Out:
#        LAST_ZIP  Counts
# 0  ACEVEDO33173       1
# 1    ADAMS37421       1
# 2    ADAMS38501       3
# 3    ADAMS47374       1
# 4    ADAMS65807       1

# %%
non_duplicates = table.loc[table['Counts'] == 1]

# %%
non_duplicates
# Out:
#             LAST_ZIP  Counts
# 0       ACEVEDO33173       1
# 1         ADAMS37421       1
# 3         ADAMS47374       1
# 4         ADAMS65807       1
# 7         ADAMS74601       1
# 8         ADAMS75025       1
# 9         ADAMS78222       1
# 10        AHMED13204       1
# 11        AHMED55407       1
# 13     ALBRECHT21601       1
# 14    ALEXANDER30339       1
# 15          ALI44146       1
# 17        ALLEN27703       1
# 18        ALLEN32207       1
# 19        ALLEN35960       1
# 20        ALLEN37343       1
# 21        ALLEN48917       1
# 24        ALLEN74146       1
# 25        ALLEN93291       1
# 26       ALONSO33012       1
# 27      ALVAREZ33010       1
# 28      ALVAREZ33013       1
# 30      ALVAREZ91331       1
# 31     ANDERSON37087       1
# 32     ANDERSON37214       1
# 33     ANDERSON37388       1
# 34     ANDERSON39401       1
# 37     ANDERSON55108       1
# 38     ANDERSON55126       1
# 39     ANDERSON55330       1
# ...              ...     ...
# ...
