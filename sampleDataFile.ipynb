# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
from pathlib import Path

pd.set_option("display.max_columns", 500)

# %%
# yearFile valid over set [2012 to 2017]
yearFile = lambda y: Path("data",f"Medicare_Provider_Util_Payment_PUF_CY20{y}.txt")

# %%
# find columns to keep to standardize imports
toKeep = lambda c: re.search("(stdev)|(standard)",c.lower()) is None

# %%
#test
y17 = yearFile(17)
y12 = yearFile(12)
print(y17)
print(y12)
# Out:
# data/Medicare_Provider_Util_Payment_PUF_CY2017.txt
# data/Medicare_Provider_Util_Payment_PUF_CY2012.txt

# %%
# test df17
df17 = pd.read_csv(y17,sep="\t",header=0,skiprows=[1],nrows=20)
df17.head()
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1003000126                    ENKESHAFI                   ARDALAN
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0               NaN              M.D.                     M                 I
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
#
#   nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# ...

# %%
print(df17.columns.str.lower().tolist())
# Out:
# ['npi', 'nppes_provider_last_org_name', 'nppes_provider_first_name', 'nppes_provider_mi', 'nppes_credentials', 'nppes_provider_gender', 'nppes_entity_code', 'nppes_provider_street1', 'nppes_provider_street2', 'nppes_provider_city', 'nppes_provider_zip', 'nppes_provider_state', 'nppes_provider_country', 'provider_type', 'medicare_participation_indicator', 'place_of_service', 'hcpcs_code', 'hcpcs_description', 'hcpcs_drug_indicator', 'line_srvc_cnt', 'bene_unique_cnt', 'bene_day_srvc_cnt', 'average_medicare_allowed_amt', 'average_submitted_chrg_amt', 'average_medicare_payment_amt', 'average_medicare_standard_amt']

# %% [markdown]
# df.shape #(56817691, 25)

# %%
# creating sampledata for CMS PUF file:
def sampleData(out=Path("data","sample.csv"), sampleSize=200000, start=12, end=17, fileGenerator=yearFile, keepCondition=toKeep):
    for y in range(start,end+1):
        df = pd.read_csv(fileGenerator(y),sep="\t",header=0,skiprows=[1],usecols=keepCondition)
        df.columns = df.columns.str.lower()
        year = 2000 + y
        df["year"] = 2000 + y
        if y == start:
            df.sample(sampleSize).to_csv(out)
        else:
            df.sample(sampleSize).to_csv(out, mode='a', header=False)
        print(f"Finished year {year}")

# %%
#sampleData()   #to make the sample.csv file
